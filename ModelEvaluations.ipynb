# %%
import numpy as np
# Set random seed for reproducibility
np.random.seed(42)
# Generate synthetic data

x = 2 * np.random.rand(100, 1) # 100 samples, 1 feature
y = 4 + 3 * x.flatten() + np.random.randn(100) # Linear relation with noise

# %%
print("Feature values (X):")
print(x[:10]) # show first 10 samples
print("\nTarget values (y):")
print(y[:10]) # show first 10 target values
# Out:
# Feature values (X):
# [[0.74908024]
#  [1.90142861]
#  [1.46398788]
#  [1.19731697]
#  [0.31203728]
#  [0.31198904]
#  [0.11616722]
#  [1.73235229]
#  [1.20223002]
#  [1.41614516]]
#
# Target values (y):
# [6.33428778 9.40527849 8.48372443 5.60438199 4.71643995 5.29307969
#  5.82639572 8.67878666 6.79819647 7.74667842]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.1, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

mae_b = mean_absolute_error(y_test, y_pred)

# %%
from sklearn.metrics import mean_absolute_error

mse_b = mean_squared_error(y_test, y_pred)

# %%
from sklearn.metrics import mean_absolute_error

rmse_b = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
from sklearn.metrics import mean_absolute_error

r2_b = r2_score(y_test, y_pred)

# %%
def msq(y, y_pred):
    means_squared_error = np.mean((y - y_pred)**2)
    return means_squared_error

# %%
def r2_score(y,pred_y):
    ss_residual = np.sum((y - y_pred)**2)
    ss_total = np.sum((y - mean_y)**2)
    r_squared = 1 - (ss_residual / ss_total)
    return r_squared

# %%
def rmsq(y, y_pred):
    r_means_squared_error = np.sqrt(np.mean((y - y_pred)**2))
    return r_means_squared_error

# %%
def mae(y,y_pred):
    mean_absolute_error = (np.mean(np.abs(y - y_pred))) # Take the absolute value of the differences
    return mean_absolute_error

# %%
print ("Built-Ins:")
print("Mean Absolute Error:", mae_b)
print("Mean Squared Error:", mse_b)
print("Root Mean Squared Error:", rmse_b)
print("Root Mean Squared Error:", r2_b)
# Out:
# Built-Ins:
# Mean Absolute Error: 0.6692040088716491
# Mean Squared Error: 0.7611865046696267
# Root Mean Squared Error: 0.8724600304137873
# Root Mean Squared Error: 0.7472086497420949

# %%
y_pred = model.predict(x_test)
print ("Customs:")
print("Mean Absolute Error:", mae(y_test,y_pred))
print("Mean Squared Error:", msq(y_test,y_pred))
print("Root Mean Squared Error:", rmsq(y_test,y_pred))
print("Root Mean Squared Error:", r2_score(y_test,y_pred))
# Out:
# Customs:
# Mean Absolute Error: 0.6692040088716491
# Mean Squared Error: 0.7611865046696267
# Root Mean Squared Error: 0.8724600304137873
# Root Mean Squared Error: 0.7494125864414899

# %%
import pandas as pd
df = pd.read_csv("cancer.csv")

# %%
display(df)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.drop('id',inplace=True,axis=1) #Drop Id column

# %%
x= df.iloc[:,1:] #Set our training data
x.drop('Unnamed: 32',inplace=True,axis=1) #Drop Id column

y = df.iloc[:,0] #Set target labels

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=42)

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
# Initialize model with k = 3
knn = KNeighborsClassifier(n_neighbors=3)
# Train the model
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
    y_pred = knn.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix k=3')
plt.show()

# %%
def conf_matrix(y_test, y_pred):
    cm = [[0, 0], [0, 0]]

    class_mapping = {'M': 1, 'B': 0}

    for true_label, pred_label in zip(y_test, y_pred):
        true_idx = class_mapping[true_label]
        pred_idx = class_mapping[pred_label]
        cm[true_idx][pred_idx] += 1
    return cm

# %%
cm = conf_matrix(y_test, y_pred)

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix k=3')
plt.show()

# %%
tn, fp = cm[0][0], cm[0][1]
fn, tp = cm[1][0], cm[1][1]


accuracy = (tp + tn) / (tp + tn + fp + fn)
precision = tp / (tp + fp)
recall = tp / (tp + fn)
f1_score = 2 * (precision * recall) / (precision + recall)

print ("Scratch:")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1_score)
# Out:
# Scratch:
# Accuracy: 0.9298245614035088
# Precision: 0.926829268292683
# Recall: 0.8837209302325582
# F1 Score: 0.9047619047619047

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy_builtin = accuracy_score(y_test, y_pred)
print(f"Built-in Accuracy: {accuracy_builtin:}")

precision_builtin = precision_score(y_test, y_pred, average='weighted')
print(f"Built-in Precision (weighted): {precision_builtin:}")

recall_builtin = recall_score(y_test, y_pred, average='weighted')
print(f"Built-in Recall (weighted): {recall_builtin:}")

f1_score_builtin = f1_score(y_test, y_pred, average='weighted')
print(f"Built-in F1 Score (weighted): {f1_score_builtin:}")
# Out:
# Built-in Accuracy: 0.9298245614035088
# Built-in Precision (weighted): 0.9297424985785546
# Built-in Recall (weighted): 0.9298245614035088
# Built-in F1 Score (weighted): 0.9294764689501532

# %%
# THE DIFFERENCE BEING PROBABLY DUE TO THE WEIGHTED AVERAGE APPROACH IN THE BUILD IN ONES COMPARED TO SIMPLE ONE IN THE SCRATCH ONE
